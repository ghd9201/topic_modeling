# %%
pip install glove==1.0.0
# Out:
# ...
#   Created wheel for glove: filename=glove-1.0.0-py3-none-any.whl size=4046 sha256=11de485a5c797b16745aa9dead448721f0900df71aa13829b7503bb28b6f62ec
#   Stored in directory: c:\users\mots\appdata\local\pip\cache\wheels\65\70\3c\2061e57833754191ebd71ad3e8b3c57ced12c4b7e259bb228c
# Successfully built glove
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ...
#   Using cached glove_python-0.1.0.tar.gz (263 kB)
# ...
#   Running setup.py clean for glove-python
# Failed to build glove-python
# ...
#     Running setup.py install for glove-python: started
#     Running setup.py install for glove-python: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\programdata\anaconda3\envs\glove\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\MoTS\\AppData\\Local\\Temp\\pip-install-mx_st5rh\\glove-python\\setup.py'"'"'; __file__='"'"'C:\\Users\\MoTS\\AppData\\Local\\Temp\\pip-install-mx_st5rh\\glove-python\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\MoTS\AppData\Local\Temp\pip-wheel-nuxtup6b'
# ...
